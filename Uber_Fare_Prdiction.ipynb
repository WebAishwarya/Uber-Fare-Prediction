# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Importing the required libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("uber.csv")
# Importing the dataset

# %%
df.head()
# 'df.head()' will display the first 5 rows of your DataFrame 'df'
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# ...

# %%
df.tail()
# 'df.tail()' will display the last 5 rows of your DataFrame 'df'
# Out:
#         Unnamed: 0                           key  fare_amount  \
# 199995    42598914  2012-10-28 10:49:00.00000053          3.0
# 199996    16382965   2014-03-14 01:09:00.0000008          7.5
# 199997    27804658  2009-06-29 00:42:00.00000078         30.9
# 199998    20259894   2015-05-20 14:56:25.0000004         14.5
# 199999    11951496  2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# ...

# %%
df.shape
# To get the total (Rows, Columns)
# Out:
# (200000, 9)

# %%
df.info()
# To get the required information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.describe()
# This will output a DataFrame containing the descriptive statistics for all numerical columns in 'df'
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# ...

# %%
df.columns
# To get the number of columns in the dataset
# Out:
# Index(['Unnamed: 0', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 0','key'], axis=1)
# To drop unnamed column as it isn't required

# %%
df.head()
# First 5 rows after dropping 'Unnamed: 0' and 'key' column
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df.dtypes
# To get the type of each column after dropping 'Unnamed: 0' and 'key' column
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
df.info()
# To get the required information of the dataset after dropping 'Unnamed: 0' and 'key' column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        200000 non-null  float64
#  1   pickup_datetime    200000 non-null  object
#  2   pickup_longitude   200000 non-null  float64
#  3   pickup_latitude    200000 non-null  float64
#  4   dropoff_longitude  199999 non-null  float64
#  5   dropoff_latitude   199999 non-null  float64
#  6   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 10.7+ MB

# %%
df.describe()
# To get statistics of each columns after dropping 'Unnamed: 0' and 'key' column
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  200000.000000     200000.000000    200000.000000      199999.000000
# mean       11.359955        -72.527638        39.935885         -72.525292
# std         9.901776         11.437787         7.720539          13.117408
# min       -52.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734796         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967154        40.767158         -73.963658
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count
# count     199999.000000    200000.000000
# mean          39.923890         1.684535
# std            6.794829         1.385997
# min         -881.985513         0.000000
# 25%           40.733823         1.000000
# 50%           40.753042         1.000000
# ...

# %%
df.isnull()
# The df.isnull() method in Pandas is used to check for missing or NaN (Not a Number) values in a DataFrame 'df'.
# Filling missing values
# Value Present - 'False'
# Value Absent - 'True'
# Out:
#         fare_amount  pickup_datetime  pickup_longitude  pickup_latitude  \
# 0             False            False             False            False
# 1             False            False             False            False
# 2             False            False             False            False
# 3             False            False             False            False
# 4             False            False             False            False
# ...             ...              ...               ...              ...
# 199995        False            False             False            False
# 199996        False            False             False            False
# 199997        False            False             False            False
# 199998        False            False             False            False
# 199999        False            False             False            False
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %%
df.isnull().sum()
# Calculates the number of missing values in each column of the DataFrame 'df',
# resulting in a Series where each value represents the count of missing values in the corresponding column.
# True - 1
# False - 0
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df.isnull().sum().sum()
# The expression 'df.isnull().sum().sum()' calculates the total number of missing values in the entire DataFrame.
# Out:
# 2

# %%
df['dropoff_latitude'].fillna(value=df['dropoff_latitude'].mean(),inplace = True)
df['dropoff_longitude'].fillna(value=df['dropoff_longitude'].median(),inplace = True)
# These lines of code are using Pandas to fill missing values in the
# 'dropoff_latitude' and 'dropoff_longitude' columns of the DataFrame 'df'.

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
df.pickup_datetime = pd.to_datetime(df.pickup_datetime, errors='coerce',utc=True)
# Column pickup_datetime is in wrong format (object). Convert it to DateTime Format
# If 'coerce', then invalid parsing will be set as NaN

# %%
df.dtypes
# Out:
# fare_amount                      float64
# pickup_datetime      datetime64[ns, UTC]
# pickup_longitude                 float64
# pickup_latitude                  float64
# dropoff_longitude                float64
# dropoff_latitude                 float64
# passenger_count                    int64
# dtype: object

# %%
df.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2         12.9 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df = df.assign(hour = df.pickup_datetime.dt.hour,
              day = df.pickup_datetime.dt.day,
              month = df.pickup_datetime.dt.month,
              year = df.pickup_datetime.dt.year,
              dayofweek = df.pickup_datetime.dt.dayofweek,
              dayName = df.pickup_datetime.dt.day_name()
              )
# To segregate each time of date and time - (hour, day, month, year, dayofweek, day_name)

# %%
df.head()
# hour, day, month, year, dayofweek, day_name columns are added and printing first 5 rows
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2         12.9 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  hour  day  month  \
# 0         -73.999512         40.723217                1    19    7      5
# 1         -73.994710         40.750325                1    20   17      7
# 2         -73.962565         40.772647                1    21   24      8
# 3         -73.965316         40.803349                3     8   26      6
# 4         -73.973082         40.761247                5    17   28      8
#
#    year  dayofweek   dayName
# 0  2015          3  Thursday
# ...

# %%
df.describe()
# Only for quantitative columns
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  200000.000000     200000.000000    200000.000000      200000.000000
# mean       11.359955        -72.527638        39.935885         -72.525299
# std         9.901776         11.437787         7.720539          13.117375
# min       -52.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734796         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967154        40.767158         -73.963659
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count           hour            day  \
# count     200000.000000    200000.000000  200000.000000  200000.000000
# mean          39.923890         1.684535      13.491335      15.704670
# std            6.794812         1.385997       6.515531       8.687409
# ...

# %%
x = df['fare_amount'].value_counts()
# The line x = df['fare_amount'].value_counts() is creating a Pandas Series named 'x'
# that contains the counts of unique values in the 'fare_amount' column of the DataFrame 'df'.
# list(Series)
# counts are sorted in descending order ie. 1st count is max count

# %%
print(type(x))
print("Max count =",x[6.50])
x
#
# Out:
# <class 'pandas.core.series.Series'>
# Max count = 9684
# 6.50      9684
# 4.50      8247
# 8.50      7521
# 5.70      5858
# 5.30      5838
#           ...
# 140.25       1
# 190.00       1
# 45.16        1
# 28.20        1
# 89.10        1
# Name: fare_amount, Length: 1244, dtype: int64

# %%
# Drop the column 'pickup_datetime' using drop()
# 'axis = 1' drops the specified column

df = df.drop('pickup_datetime', axis = 1)

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 0         40.723217                1    19    7      5  2015          3
# 1         40.750325                1    20   17      7  2009          4
# 2         40.772647                1    21   24      8  2009          0
# 3         40.803349                3     8   26      6  2009          4
# 4         40.761247                5    17   28      8  2014          3
#
#     dayName
# 0  Thursday
# 1    Friday
# 2    Monday
# 3    Friday
# 4  Thursday

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# hour                   int64
# day                    int64
# month                  int64
# year                   int64
# dayofweek              int64
# dayName               object
# dtype: object

# %%
df.drop(["dayName"], axis=1, inplace=True)

# %%
number_of_columns = len(df.columns)
number_of_columns
# Out:
# 11

# %%
print(df)
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               7.5        -73.999817        40.738354         -73.999512
# 1               7.7        -73.994355        40.728225         -73.994710
# 2              12.9        -74.005043        40.740770         -73.962565
# 3               5.3        -73.976124        40.790844         -73.965316
# 4              16.0        -73.925023        40.744085         -73.973082
# ...             ...               ...              ...                ...
# 199995          3.0        -73.987042        40.739367         -73.986525
# 199996          7.5        -73.984722        40.736837         -74.006672
# 199997         30.9        -73.986017        40.756487         -73.858957
# 199998         14.5        -73.997124        40.725452         -73.983215
# 199999         14.1        -73.984395        40.720077         -73.985508
#
#         dropoff_latitude  passenger_count  hour  day  month  year  dayofweek
# ...

# %%
# Boxplot to check the outliers
df.plot(kind = "box", subplots = False, layout = (7,2), figsize = (15,20))
# Out:
# <Axes: >

# %%
df.plot(kind = "box", subplots = True, layout = (7,2), figsize = (15,20))
# 7 rows x 2 columns = 14 spaces for 14 subplots ; where 14 subplots are possible and 11 < 14 : OK
# Out:
# fare_amount             Axes(0.125,0.786098;0.352273x0.0939024)
# pickup_longitude     Axes(0.547727,0.786098;0.352273x0.0939024)
# pickup_latitude         Axes(0.125,0.673415;0.352273x0.0939024)
# dropoff_longitude    Axes(0.547727,0.673415;0.352273x0.0939024)
# dropoff_latitude        Axes(0.125,0.560732;0.352273x0.0939024)
# passenger_count      Axes(0.547727,0.560732;0.352273x0.0939024)
# hour                    Axes(0.125,0.448049;0.352273x0.0939024)
# day                  Axes(0.547727,0.448049;0.352273x0.0939024)
# month                   Axes(0.125,0.335366;0.352273x0.0939024)
# year                 Axes(0.547727,0.335366;0.352273x0.0939024)
# dayofweek               Axes(0.125,0.222683;0.352273x0.0939024)
# dtype: object

# %%
# Clip function
a = np.arange(10,100,10) # Considers from 10 to 99 with the step size of 10
a1 = np.clip(a,30,60)     # np.clip(list, lowerlimit, upperlimit)

print("Before clipping : ",a)
print("After clipping : ",a1)
# Out:
# Before clipping :  [10 20 30 40 50 60 70 80 90]
# After clipping :  [30 30 30 40 50 60 60 60 60]

# %%
# Elimination of the outliers
# Using the InterQuartile Range to fill the values

def remove_outlier(df1, col):
    Q1 = df1[col].quantile(0.25)
    Q2 = df1[col].quantile(0.50)
    Q3 = df1[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_whisker = Q1-1.5*IQR
    upper_whisker = Q3+1.5*IQR
    print("-----***************************************************************************-----")
    print("col = ",col,"Q1 = ",Q1,"Q2 = ",Q2,"Q3 = ",Q3)
    print("-----***************************************************************************-----")
    df1[col] = np.clip(df1[col], lower_whisker, upper_whisker)
    return df1

def treat_outliers_all(df1, col_list):
    print("col_list,col_list")
    for c in col_list:
        df1 = remove_outlier(df1, c)
    return df1

# %%
df = treat_outliers_all(df, df.columns)
# Out:
# col_list,col_list
# -----***************************************************************************-----
# col =  fare_amount Q1 =  6.0 Q2 =  8.5 Q3 =  12.5
# -----***************************************************************************-----
# -----***************************************************************************-----
# col =  pickup_longitude Q1 =  -73.992065 Q2 =  -73.98182299999999 Q3 =  -73.96715350000001
# -----***************************************************************************-----
# -----***************************************************************************-----
# col =  pickup_latitude Q1 =  40.73479575 Q2 =  40.752592 Q3 =  40.767158
# -----***************************************************************************-----
# -----***************************************************************************-----
# col =  dropoff_longitude Q1 =  -73.991407 Q2 =  -73.98009300000001 Q3 =  -73.96365875
# ...

# %%
# Boxplot shows that dataset is free from outliers
df.plot(kind = "box", subplots = True, layout = (7,2), figsize=(15,20))
# Out:
# fare_amount             Axes(0.125,0.786098;0.352273x0.0939024)
# pickup_longitude     Axes(0.547727,0.786098;0.352273x0.0939024)
# pickup_latitude         Axes(0.125,0.673415;0.352273x0.0939024)
# dropoff_longitude    Axes(0.547727,0.673415;0.352273x0.0939024)
# dropoff_latitude        Axes(0.125,0.560732;0.352273x0.0939024)
# passenger_count      Axes(0.547727,0.560732;0.352273x0.0939024)
# hour                    Axes(0.125,0.448049;0.352273x0.0939024)
# day                  Axes(0.547727,0.448049;0.352273x0.0939024)
# month                   Axes(0.125,0.335366;0.352273x0.0939024)
# year                 Axes(0.547727,0.335366;0.352273x0.0939024)
# dayofweek               Axes(0.125,0.222683;0.352273x0.0939024)
# dtype: object

# %%
df['fare_amount'].value_counts().plot(kind='bar', figsize=(100,50), color="red")
                                                #(width, height)
# Out:
# <Axes: >

# %%
df['hour'].value_counts().plot(kind='bar', figsize=(10,5), color="red")
                                            #(width, height)
# Out:
# <Axes: >

# %%
h = df['hour']
f = df['fare_amount']
plt.plot(h,f)
plt.show()

# %%
# Finding incorrect latitude (Less than -90 or greater than 90) and longitude (greater than 180 or less than -180)
incorrect_coordinates = df.loc[(df.pickup_latitude > 90) | (df.pickup_latitude < -90) |
                              (df.dropoff_latitude > 90) | (df.dropoff_latitude < -90) |
                              (df.pickup_longitude > 180) | (df.pickup_longitude < -180) |
                              (df.dropoff_longitude > 90) | (df.dropoff_longitude < -90)
                              ]

# %%
incorrect_coordinates
# Out:
# Empty DataFrame
# Columns: [fare_amount, pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude, passenger_count, hour, day, month, year, dayofweek]
# Index: []

# %%
df.drop(incorrect_coordinates, inplace = True, errors = 'ignore')

# %%
df
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0              7.50        -73.999817        40.738354         -73.999512
# 1              7.70        -73.994355        40.728225         -73.994710
# 2             12.90        -74.005043        40.740770         -73.962565
# 3              5.30        -73.976124        40.790844         -73.965316
# 4             16.00        -73.929786        40.744085         -73.973082
# ...             ...               ...              ...                ...
# 199995         3.00        -73.987042        40.739367         -73.986525
# 199996         7.50        -73.984722        40.736837         -74.006672
# 199997        22.25        -73.986017        40.756487         -73.922036
# 199998        14.50        -73.997124        40.725452         -73.983215
# 199999        14.10        -73.984395        40.720077         -73.985508
#
#         dropoff_latitude  passenger_count  hour  day  month  year  dayofweek
# ...

# %%
# !pip install haversine

# %%
# Calculate the distance using Haversine to calculate the distance between to points. Can't use Eucladian as it is for flat surface.
import haversine as hs
travel_dist = []
for pos in range(len(df['pickup_longitude'])):
    long1,lati1,long2,lati2 = [df['pickup_longitude'][pos],df['pickup_latitude'][pos],df['dropoff_longitude'][pos],df['dropoff_latitude'][pos]]
    loc1 = (lati1,long1)
    loc2 = (lati2,long2)
    c = hs.haversine(loc1,loc2)
    travel_dist.append(c)

print(travel_dist)
df['dist_travel_km'] = travel_dist
df.head()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.929786        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 0         40.723217              1.0    19    7      5  2015          3
# 1         40.750325              1.0    20   17      7  2009          4
# ...

# %%
# Uber doesn't travel over 130 kms so minimize the distance
df = df[(df.dist_travel_km >= 1) & (df.dist_travel_km <= 130)]
print("Remaining observations in the dataset : ", df.shape)
# Out:
# Remaining observations in the dataset :  (163040, 12)

# %%
bool_df = df.isnull()
bool_df
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             False             False            False              False
# 1             False             False            False              False
# 2             False             False            False              False
# 3             False             False            False              False
# 4             False             False            False              False
# ...             ...               ...              ...                ...
# 199994        False             False            False              False
# 199996        False             False            False              False
# 199997        False             False            False              False
# 199998        False             False            False              False
# 199999        False             False            False              False
#
#         dropoff_latitude  passenger_count   hour    day  month   year  \
# ...

# %%
# Free of null values, no correlation exists since r = 0 (False is a constant value which is not related to the index of each row in the df)
sns.heatmap(bool_df)
# Out:
# <Axes: >

# %%
sns.heatmap(bool_df.corr())
#r = 1
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <Axes: >

# %%
# Function to find the correlation
corr = df.corr()

# %%
corr
# Out:
#                    fare_amount  pickup_longitude  pickup_latitude  \
# fare_amount           1.000000          0.193177        -0.119469
# pickup_longitude      0.193177          1.000000         0.425309
# pickup_latitude      -0.119469          0.425309         1.000000
# dropoff_longitude     0.258583          0.241569         0.148761
# dropoff_latitude     -0.137745          0.169203         0.358836
# passenger_count       0.015056         -0.012892        -0.016186
# hour                 -0.029760          0.013057         0.031484
# day                   0.001607         -0.004459         0.002907
# month                 0.031339          0.000863         0.001627
# year                  0.161861          0.014862        -0.016172
# dayofweek             0.009264         -0.028392        -0.044618
# dist_travel_km        0.798926          0.130003        -0.143530
#
#                    dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %%
plt.subplots(figsize = (12,8))
sns.heatmap(df.corr(), annot = True)  # Correlation Heatmap (Light values means highly correlated)
# Out:
# <Axes: >

# %%
# Dividing the dataset into feature and target values
df.columns
# Out:
# Index(['fare_amount', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'hour',
#        'day', 'month', 'year', 'dayofweek', 'dist_travel_km'],
#       dtype='object')

# %%
# Since all columns except "fare_amount" are the features, the following can be done
x = df[df.columns[1:]]  # since 0th column is fare_amount
x
# Out:
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# 2             -74.005043        40.740770         -73.962565
# 3             -73.976124        40.790844         -73.965316
# 4             -73.929786        40.744085         -73.973082
# ...                  ...              ...                ...
# 199994        -73.983070        40.760770         -73.972972
# 199996        -73.984722        40.736837         -74.006672
# 199997        -73.986017        40.756487         -73.922036
# 199998        -73.997124        40.725452         -73.983215
# 199999        -73.984395        40.720077         -73.985508
#
#         dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 0              40.723217              1.0    19    7      5  2015          3
# ...

# %%
y = df['fare_amount']
y
# Out:
# 0          7.50
# 1          7.70
# 2         12.90
# 3          5.30
# 4         16.00
#           ...
# 199994    12.00
# 199996     7.50
# 199997    22.25
# 199998    14.50
# 199999    14.10
# Name: fare_amount, Length: 163040, dtype: float64

# %%
# Dividing the dataset into training and testing dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.70,random_state=7)   # 30% for training, 70% for testing or evaluation

# %%
x_train
# Out:
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 85111         -73.979022        40.777218         -74.006340
# 134870        -74.001322        40.731158         -74.008248
# 82644         -73.985282        40.751895         -73.977094
# 110503        -73.965110        40.764404         -73.972360
# 95194         -73.988655        40.737095         -74.003300
# ...                  ...              ...                ...
# 81555         -73.983937        40.773500         -73.996047
# 65586         -73.929786        40.773702         -73.922036
# 13187         -73.971954        40.782089         -73.957771
# 60932         -73.968068        40.799880         -73.984100
# 75614         -73.999518        40.726767         -73.987127
#
#         dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 85111          40.739864              3.0    21   27     11  2010          5
# ...

# %%
x_test
# Out:
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 4601          -73.980368        40.745082         -73.965373
# 16992         -73.971989        40.750650         -73.922036
# 22135         -73.988637        40.737163         -73.990168
# 143093        -73.979542        40.781737         -73.982103
# 42087         -74.000102        40.761207         -73.991612
# ...                  ...              ...                ...
# 43618         -73.979320        40.749995         -74.033029
# 14485         -73.950343        40.783722         -73.968238
# 154067        -74.003772        40.748191         -73.966122
# 26162         -73.983575        40.765592         -73.983882
# 175834        -73.975002        40.790077         -73.996935
#
#         dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 4601           40.756930              3.5    23   16      5  2011          0
# ...

# %%
y_train
# Out:
# 85111     10.1
# 134870     6.5
# 82644      4.9
# 110503     5.7
# 95194      7.0
#           ...
# 81555      8.5
# 65586     19.7
# 13187      5.5
# 60932     17.3
# 75614      9.0
# Name: fare_amount, Length: 48912, dtype: float64

# %%
y_test
# Out:
# 4601       6.50
# 16992     22.25
# 22135      7.30
# 143093    12.10
# 42087      5.30
#           ...
# 43618     22.25
# 14485      8.00
# 154067    10.50
# 26162      9.00
# 175834    10.90
# Name: fare_amount, Length: 114128, dtype: float64

# %%
# 100% entries or examples
len(y)
# Out:
# 163040

# %%
# 30% of training
len(y_train)
# Out:
# 48912

# %%
# 70% of testing
len(y_test)
# Out:
# 114128

# %%
len(y_train) + len(y_test)    # Total becomes 100%
# Out:
# 163040

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regression.intercept_  # To find the linear intercept
# Out:
# 3802.528288839196

# %%
regression.coef_    # To find the linear coefficients ie. parameters (11 features so 11 parameters)
# Out:
# array([ 2.73957378e+01, -7.30933902e+00,  2.19325839e+01, -1.73267464e+01,
#         5.93910484e-02,  9.70449327e-03,  5.11074159e-03,  6.52947006e-02,
#         4.25071042e-01, -3.72182066e-02,  1.79572436e+00])

# %%
for i in range(0,len(regression.coef_)):
    print("theta", i,"=",regression.coef_[i])
# Out:
# theta 0 = 27.395737782673184
# theta 1 = -7.309339024838826
# theta 2 = 21.93258393549863
# theta 3 = -17.32674642882707
# theta 4 = 0.05939104844301779
# theta 5 = 0.00970449326769085
# theta 6 = 0.005110741589283541
# theta 7 = 0.06529470062479152
# theta 8 = 0.42507104159971304
# theta 9 = -0.03721820662179198
# theta 10 = 1.7957243586630343

# %%
y_pred = regression.predict(x_test)   # To predict the target values

# %%
# Assuming y_test and y_pred are arrays/lists containing actual and predicted labels respectively
comparison = pd.DataFrame({"Actual Label": y_test, "Predicted Label": y_pred})

# %%
comparison
# Out:
#         Actual Label  Predicted Label
# 4601            6.50         8.459790
# 16992          22.25        15.844342
# 22135           7.30         7.152703
# 143093         12.10        10.100598
# 42087           5.30         6.013980
# ...              ...              ...
# 43618          22.25        19.074790
# 14485           8.00         8.770294
# 154067         10.50        10.161324
# 26162           9.00         8.149139
# 175834         10.90        11.716657
#
# [114128 rows x 2 columns]

# %%
comparison.reset_index()
# Out:
#          index  Actual Label  Predicted Label
# 0         4601          6.50         8.459790
# 1        16992         22.25        15.844342
# 2        22135          7.30         7.152703
# 3       143093         12.10        10.100598
# 4        42087          5.30         6.013980
# ...        ...           ...              ...
# 114123   43618         22.25        19.074790
# 114124   14485          8.00         8.770294
# 114125  154067         10.50        10.161324
# 114126   26162          9.00         8.149139
# 114127  175834         10.90        11.716657
#
# [114128 rows x 3 columns]

# %%
comparison.reset_index().drop(["index"], axis=1)
# Out:
#         Actual Label  Predicted Label
# 0               6.50         8.459790
# 1              22.25        15.844342
# 2               7.30         7.152703
# 3              12.10        10.100598
# 4               5.30         6.013980
# ...              ...              ...
# 114123         22.25        19.074790
# 114124          8.00         8.770294
# 114125         10.50        10.161324
# 114126          9.00         8.149139
# 114127         10.90        11.716657
#
# [114128 rows x 2 columns]

# %%
sns.heatmap(comparison.corr())
# Nearly strong positive correlation
# r=1 & r=0.84 ~~1
# Out:
# <Axes: >

# %%
# Metrics Evaluation using R2, Mean Squared Error, Root Mean Squared Error
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# r2 score = 1
# (y-Y^) = 0.6 (Not perfect in prediction)
# Out:
# 0.6812580088487672

# %%
from sklearn.metrics import mean_squared_error

# %%
MSE = mean_squared_error(y_test,y_pred)

# %%
MSE
# 1/2m {Summation of (Actual - Predicted)^2}
# Out:
# 9.123097898885892

# %%
RMSE = np.sqrt(MSE)
# Square Root (MSE) = RMSE

# %%
RMSE
# Out:
# 3.0204466389734304

# %%
# Random Forest Regression
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=100)  # Here n_estimators means number of trees you want to build before making the prediction

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(x_test)

# %%
y_pred
# Out:
# array([ 6.162 , 21.5705,  7.0825, ..., 11.1035,  7.72  , 12.0025])

# %%
# Metrics evaluation for Random Forest
R2_Random = r2_score(y_test,y_pred)

# %%
R2_Random
# Out:
# 0.8203873598002578

# %%
MSE_Random = mean_squared_error(y_test,y_pred)

# %%
MSE_Random
# Out:
# 5.140909406072393

# %%
RMSE_Random = np.sqrt(MSE_Random)

# %%
RMSE_Random
# Out:
# 2.267357361792003

# %%
cab = df.head(25)
cab.plot(kind='bar', figsize=(26,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
